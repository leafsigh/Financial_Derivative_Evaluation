# %%
import numpy as np
import scipy as sp
import scipy.linalg as sl

# %%
# scipy.linalg.sqrtm(A, disp=True, blocksize=64)
# a = np.matrix('1 2; 3 4')
# print(a)
# [[1 2]
#  [3 4]]
#
# np.matrix([[1, 2], [3, 4]])
# matrix([[1, 2],
# #    [3, 4]])

# %%
a=np.matrix('0.000061,0.00007,0.000057;0.00007,0.000105,0.000066;0.000057,0.000066,0.000148')
a
# Out:
# matrix([[  6.10000000e-05,   7.00000000e-05,   5.70000000e-05],
#         [  7.00000000e-05,   1.05000000e-04,   6.60000000e-05],
#         [  5.70000000e-05,   6.60000000e-05,   1.48000000e-04]])

# %%
sqr=sl.sqrtm(a)
sqr
# Out:
# array([[ 0.00605152,  0.00420156,  0.00259344],
#        [ 0.00420156,  0.0089523 ,  0.00268389],
#        [ 0.00259344,  0.00268389,  0.01157889]])

# %%
a=np.array([1,2,3]).reshape(1,3)

# %%
b=np.array([[1,1,1],[1,1,1],[1,1,1]])

# %%
a.T*b
# Out:
# array([[1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3]])

# %%
def dependify(st,m,x):
    return np.matmul(np.matmul(st,m),x)

# %%
def simulation(r_s,r_euro,sig_rus,sig_sp,sig_eurox,sig_euro_eurox,s1,s2,s3,M):
    st=np.array([s1,s2,s3]).reshape(3,1)
    process=[st]
    r=np.array([r_s,r_euro,r_euro-sig_euro_eurox]).reshape(3,1)
    for i in range(731):
        X=np.random.normal(loc=0,scale=1,size=[3,1])
        st+=r*st*1.0/20+np.matmul(st.T*M,X)
        process.append(st)
    return process

# %%
simulation(0.2,0.1,np.sqrt(0.000105),np.sqrt(0.000061),np.sqrt(0.000148),-0.000004,2355.54,1364.563,3495.8,m)
# Out:
# [array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
#         [  154575.91980695]]), array([[ 3067018.85018512],
#         [   35123.422087  ],
# ...

# %%
st=np.array([1,2,3]).reshape(3,1)
min(st)
# Out:
# array([1])

# %%
def final_value(threshold,principal,coupon,process):
    check = 0
    for i in process[-90,]:
        if i[0][0]<threshold or i[1][0]<threshold or i[2][0]<threshold:
            check=1
            payoff=principal*(min(i)/initial)

# %%
for j in st>1:
    if j == False:
        b = 1
        break
# Out:
# array([[False],
#        [ True],
#        [ True]], dtype=bool)

# %%
from datetime import date

# %%
date(2019,4,11)-date(2017,4,7)
# Out:
# datetime.timedelta(734)

# %%
for i in range()
# Out:
#   File "<ipython-input-22-e3f9b14113c5>", line 1
#     for i in range()
#                     ^
# SyntaxError: invalid syntax

# %%
a=[1,2,3,4,5,6,7,8]
for i in a[-3,8]:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-ce44aa8178f6> in <module>()
#       1 a=[1,2,3,4,5,6,7,8]
# ----> 2 for i in a[-3,8]:
#       3     print(i)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
a=[1,2,3,4,5]
print(a[-3:])
# Out:
# [3, 4, 5]
